# %%
# REAL DATA

import csv
import matplotlib.pyplot as plt
import numpy as np
import math
#REAL DATA WITH 1/4
ra=[]
dec=[]
z=[]
# Open the CSV file
with open(r"C:\Users\USER\Desktop\drpdatas\new-data\16763-around 1.csv","r") as csv_file:

    # Create a CSV reader
    csv_reader = csv.reader(csv_file)

    # Read the file row by row
    for row in csv_reader:
      ra.append(row[0])
      dec.append(row[1])
      z.append(row[2])
      
for i in range(len(ra)):
  ra[i]=float(ra[i])

for j in range(len(dec)):
  dec[j]=float(dec[j])

ra_deg = ra
dec_deg = dec

L = len(ra_deg)
ra_rad =  [math.radians(degree) for degree in ra_deg]
dec_rad = [math.radians(degree) for degree in dec_deg]

def angle_func(ra1_rad,dec1_rad,ra2_rad,dec2_rad):
  a= np.sin(dec1_rad)*np.sin(dec2_rad)+np.cos(dec1_rad)*np.cos(dec2_rad)*np.cos(ra1_rad-ra2_rad)
  delta=np.arccos(a)
  return delta

angles_DD = []
size = int((L*(L-1))/2)
angles_DD = [0] * size

step = 0
for i in range(L):
  for j in range(i+1,L):
    angles_DD[step] = angle_func(ra_rad[i],dec_rad[i],ra_rad[j],dec_rad[j] )
    step += 1

print(angles_DD[:10])
# Out:
# [0.002350377739281991, 0.0015428164009375002, 0.025928850227111555, 0.028414971003918658, 0.035847598089710025, 0.0468936359407634, 0.06835405043823664, 0.07326436906505299, 0.08082747965302058, 0.09095745933292104]

# %%
#DD Plot
B=60
plt.hist(angles_DD,bins=B, edgecolor="black")
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[2], line 3
#       1 #DD Plot
#       2 B=60
# ----> 3 plt.hist(angles_DD,bins=B, edgecolor="black")
#
# File c:\Users\USER\anaconda3\Lib\site-packages\matplotlib\pyplot.py:2645, in hist(x, bins, range, density, weights, cumulative, bottom, histtype, align, orientation, rwidth, log, color, label, stacked, data, **kwargs)
#    2639 @_copy_docstring_and_deprecators(Axes.hist)
#    2640 def hist(
#    2641         x, bins=None, range=None, density=False, weights=None,
#    2642         cumulative=False, bottom=None, histtype='bar', align='mid',
#    2643         orientation='vertical', rwidth=None, log=False, color=None,
#    2644         label=None, stacked=False, *, data=None, **kwargs):
# -> 2645     return gca().hist(
#    2646         x, bins=bins, range=range, density=density, weights=weights,
#    2647         cumulative=cumulative, bottom=bottom, histtype=histtype,
#    2648         align=align, orientation=orientation, rwidth=rwidth, log=log,
#    2649         color=color, label=label, stacked=stacked,
#    2650         **({"data": data} if data is not None else {}), **kwargs)
#
# File c:\Users\USER\anaconda3\Lib\site-packages\matplotlib\__init__.py:1446, in _preprocess_data.<locals>.inner(ax, data, *args, **kwargs)
#    1443 @functools.wraps(func)
#    1444 def inner(ax, *args, data=None, **kwargs):
#    1445     if data is None:
# -> 1446         return func(ax, *map(sanitize_sequence, args), **kwargs)
#    1448     bound = new_sig.bind(ax, *args, **kwargs)
#    1449     auto_label = (bound.arguments.get(label_namer)
#    1450                   or bound.kwargs.get(label_namer))
#
# File c:\Users\USER\anaconda3\Lib\site-packages\matplotlib\axes\_axes.py:6704, in Axes.hist(self, x, bins, range, density, weights, cumulative, bottom, histtype, align, orientation, rwidth, log, color, label, stacked, **kwargs)
#    6701     stacked = True
#    6703 # Massage 'x' for processing.
# -> 6704 x = cbook._reshape_2D(x, 'x')
#    6705 nx = len(x)  # number of datasets
#    6707 # Process unit information.  _process_unit_info sets the unit and
#    6708 # converts the first dataset; then we convert each following dataset
#    6709 # one at a time.
#
# File c:\Users\USER\anaconda3\Lib\site-packages\matplotlib\cbook\__init__.py:1405, in _reshape_2D(X, name)
#    1403         is_1d = False
#    1404 xi = np.asanyarray(xi)
# -> 1405 nd = np.ndim(xi)
#    1406 if nd > 1:
#    1407     raise ValueError(f'{name} must have 2 or fewer dimensions')
#
# File <__array_function__ internals>:180, in ndim(*args, **kwargs)
#
# File c:\Users\USER\anaconda3\Lib\site-packages\numpy\core\fromnumeric.py:3148, in _ndim_dispatcher(a)
#    3086     """
#    3087     Return the cumulative product of elements along a given axis.
#    3088
#    (...)
#    3143
#    3144     """
#    3145     return _wrapfunc(a, 'cumprod', axis=axis, dtype=dtype, out=out)
# -> 3148 def _ndim_dispatcher(a):
#    3149     return (a,)
#    3152 @array_function_dispatch(_ndim_dispatcher)
#    3153 def ndim(a):
#
# KeyboardInterrupt:

# %%
#Random data

ra_original=np.random.uniform(155,165,len(ra_deg))
dec_original=np.random.uniform(5,15,len(ra_deg))

ra_degree   = [float(entry) for entry in ra_original]
dec_degree   = [float(entry) for entry in dec_original]


ra_ran_rad = [math.radians(degree) for degree in ra_degree]
dec_ran_rad = [math.radians(degree) for degree in dec_degree]

# %%
#RR Calculation

N = len(ra_deg)
size = int(N*(N-1)/2)

angles_RR = [0] * size
step = 0

for i in range(N):
  for j in range(i+1,N):
    angles_RR[step] = angle_func(ra_rad[i],dec_rad[i],ra_rad[j],dec_rad[j])
    step += 1

# %%
#RR Histogram

plt.hist(angles_RR, bins=B,edgecolor="black")
# Out:
# (array([2.39230e+04, 6.81810e+04, 1.10378e+05, 1.49485e+05, 1.84900e+05,
#         2.19875e+05, 2.50008e+05, 2.81003e+05, 3.08149e+05, 3.32500e+05,
#         3.54652e+05, 3.76036e+05, 3.94019e+05, 4.09699e+05, 4.23192e+05,
#         4.33543e+05, 4.43275e+05, 4.48080e+05, 4.51688e+05, 4.52991e+05,
#         4.54355e+05, 4.54187e+05, 4.49976e+05, 4.46578e+05, 4.40642e+05,
#         4.31931e+05, 4.22269e+05, 4.09107e+05, 3.96977e+05, 3.80055e+05,
#         3.63298e+05, 3.48616e+05, 3.29268e+05, 3.11284e+05, 2.91124e+05,
#         2.69924e+05, 2.48694e+05, 2.26343e+05, 2.04235e+05, 1.81420e+05,
#         1.55415e+05, 1.29176e+05, 1.02153e+05, 7.78150e+04, 6.11140e+04,
#         4.84740e+04, 3.79150e+04, 2.92440e+04, 2.27310e+04, 1.69470e+04,
#         1.25560e+04, 9.08000e+03, 6.21000e+03, 4.15600e+03, 2.55700e+03,
#         1.55400e+03, 8.18000e+02, 3.78000e+02, 1.60000e+02, 4.30000e+01]),
#  array([1.09468376e-05, 4.03931482e-03, 8.06768280e-03, 1.20960508e-02,
#         1.61244188e-02, 2.01527867e-02, 2.41811547e-02, 2.82095227e-02,
#         3.22378907e-02, 3.62662586e-02, 4.02946266e-02, 4.43229946e-02,
#         4.83513626e-02, 5.23797306e-02, 5.64080985e-02, 6.04364665e-02,
#         6.44648345e-02, 6.84932025e-02, 7.25215705e-02, 7.65499384e-02,
#         8.05783064e-02, 8.46066744e-02, 8.86350424e-02, 9.26634104e-02,
#         9.66917783e-02, 1.00720146e-01, 1.04748514e-01, 1.08776882e-01,
#         1.12805250e-01, 1.16833618e-01, 1.20861986e-01, 1.24890354e-01,
#         1.28918722e-01, 1.32947090e-01, 1.36975458e-01, 1.41003826e-01,
#         1.45032194e-01, 1.49060562e-01, 1.53088930e-01, 1.57117298e-01,
#         1.61145666e-01, 1.65174034e-01, 1.69202402e-01, 1.73230770e-01,
#         1.77259138e-01, 1.81287506e-01, 1.85315874e-01, 1.89344242e-01,
#         1.93372610e-01, 1.97400978e-01, 2.01429346e-01, 2.05457714e-01,
#         2.09486082e-01, 2.13514450e-01, 2.17542818e-01, 2.21571186e-01,
#         2.25599554e-01, 2.29627922e-01, 2.33656290e-01, 2.37684658e-01,
#         2.41713026e-01]),
#  <BarContainer object of 60 artists>)

# %%
#DR Calculation

angles_DR = []
size = int((L*(L-1))/2)
angles_DR = [0] * size

step = 0
for i in range(L):
  for j in range(i+1,L):
    angles_DR[step] = angle_func(ra_rad[i],dec_ran_rad[i],ra_rad[j],dec_ran_rad[j] )
    step += 1

print(angles_DR[:10])
# Out:
# [0.023395772231574793, 0.0016888542910130592, 0.034196897910377444, 0.05741587888540701, 0.05502873964538689, 0.04893398520549681, 0.10731957867278104, 0.10382906691455533, 0.0805103967638924, 0.1246878668404304]

# %%
#DR Plot

plt.hist(angles_DR, bins=B,edgecolor="black")
# Out:
# (array([2.33900e+04, 6.76760e+04, 1.09029e+05, 1.48672e+05, 1.85108e+05,
#         2.18881e+05, 2.49681e+05, 2.78452e+05, 3.06449e+05, 3.31801e+05,
#         3.54432e+05, 3.73701e+05, 3.91511e+05, 4.06582e+05, 4.18397e+05,
#         4.27510e+05, 4.35801e+05, 4.43410e+05, 4.46562e+05, 4.49011e+05,
#         4.50084e+05, 4.49590e+05, 4.47692e+05, 4.44435e+05, 4.38358e+05,
#         4.30074e+05, 4.21108e+05, 4.11245e+05, 3.99865e+05, 3.85904e+05,
#         3.68915e+05, 3.52455e+05, 3.33967e+05, 3.13912e+05, 2.94410e+05,
#         2.72026e+05, 2.51259e+05, 2.29294e+05, 2.06594e+05, 1.82448e+05,
#         1.57822e+05, 1.32316e+05, 1.05805e+05, 8.09160e+04, 6.32530e+04,
#         5.04330e+04, 3.97430e+04, 3.10090e+04, 2.39170e+04, 1.78910e+04,
#         1.34620e+04, 9.56000e+03, 7.09800e+03, 4.62800e+03, 3.10400e+03,
#         1.89400e+03, 1.05600e+03, 5.51000e+02, 1.76000e+02, 3.10000e+01]),
#  array([2.08282416e-05, 4.04456051e-03, 8.06829278e-03, 1.20920251e-02,
#         1.61157573e-02, 2.01394896e-02, 2.41632219e-02, 2.81869541e-02,
#         3.22106864e-02, 3.62344187e-02, 4.02581509e-02, 4.42818832e-02,
#         4.83056155e-02, 5.23293478e-02, 5.63530800e-02, 6.03768123e-02,
#         6.44005446e-02, 6.84242768e-02, 7.24480091e-02, 7.64717414e-02,
#         8.04954736e-02, 8.45192059e-02, 8.85429382e-02, 9.25666705e-02,
#         9.65904027e-02, 1.00614135e-01, 1.04637867e-01, 1.08661600e-01,
#         1.12685332e-01, 1.16709064e-01, 1.20732796e-01, 1.24756529e-01,
#         1.28780261e-01, 1.32803993e-01, 1.36827725e-01, 1.40851458e-01,
#         1.44875190e-01, 1.48898922e-01, 1.52922655e-01, 1.56946387e-01,
#         1.60970119e-01, 1.64993851e-01, 1.69017584e-01, 1.73041316e-01,
#         1.77065048e-01, 1.81088780e-01, 1.85112513e-01, 1.89136245e-01,
#         1.93159977e-01, 1.97183709e-01, 2.01207442e-01, 2.05231174e-01,
#         2.09254906e-01, 2.13278639e-01, 2.17302371e-01, 2.21326103e-01,
#         2.25349835e-01, 2.29373568e-01, 2.33397300e-01, 2.37421032e-01,
#         2.41444764e-01]),
#  <BarContainer object of 60 artists>)

# %%
fig, ax =plt.subplots()

DD_counts, DD_bins = np.histogram(angles_DD, B)
DR_counts, DR_bins = np.histogram(angles_DR,B)

ax.plot(DD_bins[:-1],DD_counts,"k")
ax.plot(DR_bins[:-1],DR_counts,"-r")

plt.show()

# %%
#DD HISTOGRAM LIST

data1 = np.random.randn(len(ra_deg))  # Generating random data for demonstration

# Compute histogram
hist_values, bin_edges = np.histogram(angles_DD, bins=B)  # Adjust the number of bins as needed

# Create a list containing histogram values
hist_list_DD = hist_values.tolist()

x_values = bin_edges

# %%
#RR HISTOGRAM LIST
data2 = np.random.randn(len(ra_deg))  # Generating random data for demonstration

# Compute histogram
hist_values, bin_edges = np.histogram(angles_RR, bins=B)  # Adjust the number of bins as needed

# Create a list containing histogram values
hist_list_RR = hist_values.tolist()

print(hist_list_RR)
# Out:
# [23923, 68181, 110378, 149485, 184900, 219875, 250008, 281003, 308149, 332500, 354652, 376036, 394019, 409699, 423192, 433543, 443275, 448080, 451688, 452991, 454355, 454187, 449976, 446578, 440642, 431931, 422269, 409107, 396977, 380055, 363298, 348616, 329268, 311284, 291124, 269924, 248694, 226343, 204235, 181420, 155415, 129176, 102153, 77815, 61114, 48474, 37915, 29244, 22731, 16947, 12556, 9080, 6210, 4156, 2557, 1554, 818, 378, 160, 43]

# %%
#DR HISTOGRAM LIST
data3 = np.random.randn(len(ra_deg))  # Generating random data for demonstration

# Compute histogram
hist_values, bin_edges = np.histogram(angles_DR, bins=B)  # Adjust the number of bins as needed

# Create a list containing histogram values
hist_list_DR = hist_values.tolist()

print(hist_list_DR)
# Out:
# [23390, 67676, 109029, 148672, 185108, 218881, 249681, 278452, 306449, 331801, 354432, 373701, 391511, 406582, 418397, 427510, 435801, 443410, 446562, 449011, 450084, 449590, 447692, 444435, 438358, 430074, 421108, 411245, 399865, 385904, 368915, 352455, 333967, 313912, 294410, 272026, 251259, 229294, 206594, 182448, 157822, 132316, 105805, 80916, 63253, 50433, 39743, 31009, 23917, 17891, 13462, 9560, 7098, 4628, 3104, 1894, 1056, 551, 176, 31]

# %%
#CORRELATION FUNCTION

#w = 1 + DD/RR - 2 *DR/RR

w = 1 + np.divide(hist_list_DD, hist_list_RR) - 2 * np.divide(hist_list_DR, hist_list_RR)
 
print(w)
# Out:
# [ 0.04455963  0.01481351  0.02444328  0.01087735 -0.00224986  0.0090415
#   0.00261592  0.01815639  0.01103362  0.00420451  0.00124065  0.01241902
#   0.01273035  0.01521605  0.02266111  0.02783115  0.03372173  0.02084449
#   0.02269708  0.01757209  0.01880028  0.02024276  0.01015165  0.00959743
#   0.01036669  0.0085986   0.00549886 -0.01045203 -0.01454996 -0.03077976
#  -0.03092227 -0.02202423 -0.0285421  -0.0168849  -0.02257457 -0.01557475
#  -0.02062776 -0.02607547 -0.02310084 -0.01133282 -0.03097513 -0.04861584
#  -0.07150059 -0.07970186 -0.07000033 -0.08082684 -0.09642622 -0.12070852
#  -0.10435089 -0.11140615 -0.14431348 -0.10572687 -0.28599034 -0.22714148
#  -0.42784513 -0.43758044 -0.58190709 -0.91534392 -0.2         0.55813953]

# %%
x_values = [i for i in range(B)]
#plt.xlim(0,10)
plt.ylim(-0.01,0.05)
plt.scatter(x_values,w)

# %%
increment=(10*math.sqrt(2)/B)
x_values = [i*increment for i in range(B)]
#plt.yscale('log')
plt.xlim(0,10)
plt.ylim(-0.03,0.08)


plt.plot(x_values,w)
